# %% [markdown]
# <a href="https://colab.research.google.com/github/KingGuy123/ML-Practice/blob/main/Pandas_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame([[1,2,3],[4,5,6], [7,8,9]], columns = ["A", "B", "C"], index= ["A", "B", "C"])

# %% [markdown]
# df.head() shows first 5 rows by default, can also take arguments

# %%
df.head()
# Out:
#    A  B  C
# A  1  2  3
# B  4  5  6
# C  7  8  9

# %% [markdown]
# We can see giving 2 as an argument to head() function now displays 2 rows only.

# %%
df.head(2)
# Out:
#    A  B  C
# A  1  2  3
# B  4  5  6

# %% [markdown]
# df.tail() shows bottom 5 rows by default and can also take arguments.

# %%
df.tail()
# Out:
#    A  B  C
# A  1  2  3
# B  4  5  6
# C  7  8  9

# %% [markdown]
# Giving tail() an argument of 1 shows the bottom row of the data or array set.

# %%
df.tail(1)
# Out:
#    A  B  C
# C  7  8  9
